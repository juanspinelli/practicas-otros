# %%
import cv2

face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

### Cambiar entre cara.jpg y caraModificada.jpg.

our_image_color = cv2.imread("cara.jpg")
our_image_gray = cv2.cvtColor(our_image_color,cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(our_image_gray,
scaleFactor = 1.05,
minNeighbors = 5
)

print(faces)

for x, y, w, h in faces:
    our_image_rect = cv2.rectangle(our_image_color, (x,y), (x+w,y+h), (0,255,0), 3)

cv2.imshow("Face Detection", our_image_rect)
cv2.waitKey(0)
cv2.destroyAllWindows

# %%
from IPython.display import Image

# %%
Image(filename= 'bien.png', width=900, height=300)

# %%
Image(filename= 'mal.jpg', width=900, height=300)
