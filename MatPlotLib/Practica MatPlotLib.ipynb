# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 3, 5, 9], [10, 5, 15, 5])

# %%
plt.plot([1, 3, 5, 9], [10, 5, 15, 5], marker='o')

# %%
plt.plot([1, 3, 5, 9], [10, 5, 15, 5], marker='p')

# %%
plt.plot([1, 3, 5, 9], [10, 5, 15, 5], marker='p', lw=0)
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('TÍTULO')
# Out:
# Text(0.5, 1.0, 'TÍTULO')

# %%
fig = plt.figure(figsize=(7,5))
arrayUno = np.random.rand(10) * 10
arrayDos = np.random.rand(10) * 10
plt.plot(arrayUno, arrayDos, color='red', marker='o', lw=2, ls=':',
markeredgewidth=2.0, markeredgecolor='black', markersize=10,     
clip_on=False, zorder=1000000,
label='Datos Random')
plt.legend()
