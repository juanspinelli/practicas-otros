# %% [markdown]
# ### CURSO DE GIT

# %% [markdown]
# Curso completo: https://www.youtube.com/watch?v=zH3I1DZNovk&index=1&list=PL9xYXqvLX2kMUrXTvDY6GI2hgacfy0rId

# %% [markdown]
# #### Configurar Nombre
#
# - git config --global user.name "Nombre"

# %% [markdown]
# #### Configurar Mail
#
# - git config --global user.email "Email"

# %% [markdown]
# #### Configurar colores en mensajes de Git
#
# - git config --global color.ui true

# %% [markdown]
# #### Listar todas las configuraciones
#
# -  git config --global --list

# %% [markdown]
# #### Listar Consola
#
# - Clear

# %% [markdown]
# #### Iniciar Git
#
# Navegar hasta la carpeta donde van a estar los archivos
#
# - git init

# %% [markdown]
# #### Verificar estados de los archivos y modificaciones
#
# - git status

# %% [markdown]
# #### Agregar los archivos con los que se va a hacer el commit
#
# - git add .

# %% [markdown]
# #### Hacer un commit y dejar un mensaje de que se hizo en los archivos que se estan subiendo
#
# - git commit -m "Se hizo esto y aquello"

# %% [markdown]
# #### Ver que hacen los comandos
#
# - git help
# - git hel status

# %% [markdown]
# #### Ver en que rama estamos
#
# - git branch

# %% [markdown]
# #### Verificar Log
#
# - git log

# %% [markdown]
# #### Conectar con Git Hub
#
# - git remote add origin direccionDelRepositorioDeGithub

# %%
from IPython.display import Image
Image(filename='git.png')

# %% [markdown]
# #### Pull
#
# - git pull origin master --allow-unrelated-histories
